# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://results.eci.gov.in/PcResultGenJune2024/index.htm'

page = requests.get(url)

soup = BeautifulSoup(page.text, 'html')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <!-- Required meta tags -->
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=7" http-equiv="X-UA-Compatible"/>
# <meta content="no-cache, no-store, must-revalidate" http-equiv="Cache-Control"/>
# <meta content="no-cache" http-equiv="Pragma"/>
# <meta content="0" http-equiv="Expires"/>
# <meta content="300" http-equiv="refresh"/>
# <!-- Bootstrap CSS -->
# <link href="css/bootstrap.min.css" rel="stylesheet"/>
# <link href="css/custom.css" rel="stylesheet"/>
# <link href="css/responsive.css" rel="stylesheet"/>
# <link href="css/font.css" rel="stylesheet"/>
# <link href="img/icons/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <title>Election Commission of India</title>
# <style type="text/css">
# </style>
# ...

# %%
table = soup.find('table')

# %%
world_titles = table.find_all('th')

# %%
world_titles
# Out:
# [<th style="text-align: left;">Party</th>,
#  <th style="text-align:right">Won</th>,
#  <th style="text-align:right">Leading</th>,
#  <th style="text-align:right">Total</th>,
#  <th>Total</th>,
#  <th style="text-align:right">543</th>,
#  <th style="text-align:right">0</th>,
#  <th style="text-align:right">543</th>]

# %%
world_table_titles = [ title.text for title in world_titles ]

print(world_table_titles)
# Out:
# ['Party', 'Won', 'Leading', 'Total', 'Total', '543', '0', '543']

# %%
del world_table_titles [4:8]

print(world_table_titles)
# Out:
# ['Party', 'Won', 'Leading', 'Total']

# %%
import pandas 
pandas.__version__
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 import pandas
#       2 pandas.__version__
#
# ModuleNotFoundError: No module named 'pandas'

# %%
pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.1/11.5 MB 1.1 MB/s eta 0:00:11
#    ---------------------------------------- 0.1/11.5 MB 1.3 MB/s eta 0:00:09
#    ---------------------------------------- 0.1/11.5 MB 901.1 kB/s eta 0:00:13
#     --------------------------------------- 0.2/11.5 MB 893.0 kB/s eta 0:00:13
#     --------------------------------------- 0.2/11.5 MB 915.1 kB/s eta 0:00:13
#     --------------------------------------- 0.3/11.5 MB 1.0 MB/s eta 0:00:12
#     --------------------------------------- 0.3/11.5 MB 803.7 kB/s eta 0:00:14
#    - -------------------------------------- 0.3/11.5 MB 729.6 kB/s eta 0:00:16
#    - -------------------------------------- 0.3/11.5 MB 729.6 kB/s eta 0:00:16
#    - -------------------------------------- 0.3/11.5 MB 675.6 kB/s eta 0:00:17
# ...

# %%
import pandas as pd

# %%
df = pd.DataFrame(columns = world_table_titles)

df
# Out:
# Empty DataFrame
# Columns: [Party, Won, Leading, Total]
# Index: []

# %%
column_data = table.find_all('tr')

# %%
for row in column_data[1:43]:
    row_data = row.find_all('td')
    individual_row_data = [data.text.strip() for data in row_data]
    #print(individual_row_data)
    length = len(df)
    df.loc[length] = individual_row_data

# %%
df
# Out:
#                                                 Party  Won Leading Total
# 0                        Bharatiya Janata Party - BJP  240       0   240
# 1                      Indian National Congress - INC   99       0    99
# 2                                Samajwadi Party - SP   37       0    37
# 3                 All India Trinamool Congress - AITC   29       0    29
# 4                     Dravida Munnetra Kazhagam - DMK   22       0    22
# 5                                  Telugu Desam - TDP   16       0    16
# 6                        Janata Dal  (United) - JD(U)   12       0    12
# 7      Shiv Sena (Uddhav Balasaheb Thackrey) - SHSUBT    9       0     9
# 8   Nationalist Congress Party – Sharadchandra Paw...    8       0     8
# 9                                     Shiv Sena - SHS    7       0     7
# 10             Lok Janshakti Party(Ram Vilas) - LJPRV    5       0     5
# 11      Yuvajana Sramika Rythu Congress Party - YSRCP    4       0     4
# ...

# %%
df.to_csv(r'C:\Users\ASUS\Downloads\folder_output\Parlimentary_constituency_general.csv', index = False)
